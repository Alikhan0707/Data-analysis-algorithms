# %% [markdown]
# ### 1. К алгоритму kNN, реализованному на уроке, реализовать добавление весов для соседей по любому из показанных на уроке принципов.

# %%
# %matplotlib inline
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.datasets import load_iris
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap

# %%
X, y = load_iris(return_X_y=True)

X = X[:, :2]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, 
                                                    test_size=.2,
                                                    random_state=1,
                                                    stratify=y)

# %%
cmap = ListedColormap(['red', 'green', 'blue'])
plt.figure(figsize=(7, 7))
plt.scatter(X[:, 0], X[:, 1], c=y, cmap=cmap)

# %%
def e_metrics(x1, x2):
    
    distance = 0
    
    for i in range(len(x1)):
        distance += np.square(x1[i] - x2[i])
    
    return np.sqrt(distance)

# %%
def knn(x_train, y_train, x_test, k, q=0.5):
    
    answers = []
    
    for x in x_test:
        
        test_distance = []
        
        for i in range(len(x_train)):
            
            distance = e_metrics(x, x_train[i])
            # Изменения
#             test_distance.append((distance, y_train[i]))
            test_distance.append((distance + (q ** distance), y_train[i]))
            
        classes = {class_item: 0 for class_item in set(y_train)}
        
        for d in sorted(test_distance)[0:k]:
            classes[d[1]] += 1
            
        answers.append(sorted(classes, key=classes.get)[-1])
    
    return answers

# %%
def accuracy(pred, y):
    return (sum(pred == y) / len(y))

# %%
def get_graph(X_train, y_train, k):
    cmap_light = ListedColormap(['#FFAAAA', '#AAFFAA', '#00AAFF'])
    
    h = 0.2
    
    # Расчет пределов графика
    x_min, x_max = X_train[:, 0].min() - 1, X_train[:, 0].max() + 1
    y_min, y_max = X_train[:, 1].min() - 1, X_train[:, 1].max() + 1
    xx, yy = np.meshgrid(np.arange(x_min, x_max, h), np.arange(y_min, y_max, h))
    
    # Получим предсказания для всех точек
    Z = knn(X_train, y_train, np.c_[xx.ravel(), yy.ravel()], k)
    
    # Построим график
    Z = np.array(Z).reshape(xx.shape)
    plt.figure(figsize=(7, 7))
    plt.pcolormesh(xx, yy, Z, cmap=cmap_light)
    
    # Добавим на график обучающую выборку
    plt.scatter(X_train[:, 0], X_train[:, 1], c=y_train, cmap=cmap)
    plt.xlim(xx.min(), xx.max())
    plt.ylim(yy.min(), yy.max())
    plt.title(f'Трехклассовая kNN классификация при k = {k}')
    plt.show()

# %%
k = 100
k_neibs = []
accuracies = []
for i in range(1, k):
    y_pred = knn(X_train, y_train, X_test, i)
    accur = accuracy(y_pred, y_test)
    print(f'Точность алгоритма при k = {i}: {accuracy(y_pred, y_test):.3f}')
    get_graph(X_train, y_train, i)
    k_neibs.append(i)
    accuracies.append(accur)
# Out:
# Точность алгоритма при k = 1: 0.700
# Точность алгоритма при k = 2: 0.733
# Точность алгоритма при k = 3: 0.733
# Точность алгоритма при k = 4: 0.700
# Точность алгоритма при k = 5: 0.733
# Точность алгоритма при k = 6: 0.700
# Точность алгоритма при k = 7: 0.733
# Точность алгоритма при k = 8: 0.767
# Точность алгоритма при k = 9: 0.733
# Точность алгоритма при k = 10: 0.767
# Точность алгоритма при k = 11: 0.733
# Точность алгоритма при k = 12: 0.700
# Точность алгоритма при k = 13: 0.700
# Точность алгоритма при k = 14: 0.700
# Точность алгоритма при k = 15: 0.700
# Точность алгоритма при k = 16: 0.733
# Точность алгоритма при k = 17: 0.733
# Точность алгоритма при k = 18: 0.733
# Точность алгоритма при k = 19: 0.733
# Точность алгоритма при k = 20: 0.733
# Точность алгоритма при k = 21: 0.733
# Точность алгоритма при k = 22: 0.733
# Точность алгоритма при k = 23: 0.700
# Точность алгоритма при k = 24: 0.700
# Точность алгоритма при k = 25: 0.700
# Точность алгоритма при k = 26: 0.733
# Точность алгоритма при k = 27: 0.733
# Точность алгоритма при k = 28: 0.733
# Точность алгоритма при k = 29: 0.767
# Точность алгоритма при k = 30: 0.767
# Точность алгоритма при k = 31: 0.767
# Точность алгоритма при k = 32: 0.767
# Точность алгоритма при k = 33: 0.767
# Точность алгоритма при k = 34: 0.767
# Точность алгоритма при k = 35: 0.767
# Точность алгоритма при k = 36: 0.767
# Точность алгоритма при k = 37: 0.767
# Точность алгоритма при k = 38: 0.767
# Точность алгоритма при k = 39: 0.733
# Точность алгоритма при k = 40: 0.733
# Точность алгоритма при k = 41: 0.733
# Точность алгоритма при k = 42: 0.733
# Точность алгоритма при k = 43: 0.733
# Точность алгоритма при k = 44: 0.700
# Точность алгоритма при k = 45: 0.700
# Точность алгоритма при k = 46: 0.700
# Точность алгоритма при k = 47: 0.700
# Точность алгоритма при k = 48: 0.700
# Точность алгоритма при k = 49: 0.700
# Точность алгоритма при k = 50: 0.700
# Точность алгоритма при k = 51: 0.700
# Точность алгоритма при k = 52: 0.667
# Точность алгоритма при k = 53: 0.667
# Точность алгоритма при k = 54: 0.667
# Точность алгоритма при k = 55: 0.667
# Точность алгоритма при k = 56: 0.667
# Точность алгоритма при k = 57: 0.667
# Точность алгоритма при k = 58: 0.667
# Точность алгоритма при k = 59: 0.667
# Точность алгоритма при k = 60: 0.667
# Точность алгоритма при k = 61: 0.600
# Точность алгоритма при k = 62: 0.667
# Точность алгоритма при k = 63: 0.600
# Точность алгоритма при k = 64: 0.600
# Точность алгоритма при k = 65: 0.633
# Точность алгоритма при k = 66: 0.667
# Точность алгоритма при k = 67: 0.667
# Точность алгоритма при k = 68: 0.667
# Точность алгоритма при k = 69: 0.733
# Точность алгоритма при k = 70: 0.700
# Точность алгоритма при k = 71: 0.733
# Точность алгоритма при k = 72: 0.733
# Точность алгоритма при k = 73: 0.700
# Точность алгоритма при k = 74: 0.667
# Точность алгоритма при k = 75: 0.667
# Точность алгоритма при k = 76: 0.633
# Точность алгоритма при k = 77: 0.633
# Точность алгоритма при k = 78: 0.667
# Точность алгоритма при k = 79: 0.667
# Точность алгоритма при k = 80: 0.700
# Точность алгоритма при k = 81: 0.700
# Точность алгоритма при k = 82: 0.700
# Точность алгоритма при k = 83: 0.667
# Точность алгоритма при k = 84: 0.667
# Точность алгоритма при k = 85: 0.667
# Точность алгоритма при k = 86: 0.667
# Точность алгоритма при k = 87: 0.633
# Точность алгоритма при k = 88: 0.633
# Точность алгоритма при k = 89: 0.633
# Точность алгоритма при k = 90: 0.633
# Точность алгоритма при k = 91: 0.633
# Точность алгоритма при k = 92: 0.633
# Точность алгоритма при k = 93: 0.633
# Точность алгоритма при k = 94: 0.633
# Точность алгоритма при k = 95: 0.633
# Точность алгоритма при k = 96: 0.633
# Точность алгоритма при k = 97: 0.667
# Точность алгоритма при k = 98: 0.667
# Точность алгоритма при k = 99: 0.667

# %%
plt.plot(k_neibs, accuracies)
plt.xlabel('accuracy')
plt.ylabel('k-neighbours')
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %% [markdown]
# ### 2. *Написать функцию подсчета метрики качества кластеризации как среднее квадратичное внутрикластерное расстояние и построить график ее зависимости от количества кластеров k (взять от 1 до 10) для выборки данных из данного урока (создать датасет, как в методичке).
